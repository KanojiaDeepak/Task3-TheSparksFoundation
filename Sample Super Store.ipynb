# %% [markdown]
# # Presented by- Deepak Kanojia

# %% [markdown]
# # The Sparks Foundation
# ## Task 3- Exploratory Data Analysis: Retail Sample Super Store

# %% [markdown]
# ## Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Reading dataset into Pandas Dataframe

# %%
df=pd.read_csv('SampleSuperstore.csv')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# ## Exploratory data analysis

# %%
#describe numerical data
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
#describe categorical data
df.describe(include='object')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
#
#        Region         Category Sub-Category
# count    9994             9994         9994
# unique      4                3           17
# top      West  Office Supplies      Binders
# freq     3203             6026         1523

# %%
#null values in data
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#duplicate values in data
df.duplicated().sum()
# Out:
# 17

# %%
#dropping duplicate values
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (9977, 13)

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
#correlation 
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %%
sns.heatmap(df.corr(),annot=True)

# %%
#Number of unique values in each column
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.describe(include='object')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9977      9977           9977           9977        9977
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5955      5183           9977            914        1996
#
#        Region         Category Sub-Category
# count    9977             9977         9977
# unique      4                3           17
# top      West  Office Supplies      Binders
# freq     3193             6012         1522

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
sns.pairplot(df)

# %%
#Total count of different ship modes
sns.countplot(df['Ship Mode'])
plt.show()

# %%
#Total count of different segments
sns.countplot(df['Segment'])
plt.show()

# %%
df['Country'].value_counts()
# Out:
# United States    9977
# Name: Country, dtype: int64

# %%
df['City'].value_counts()
# Out:
# New York City    914
# Los Angeles      746
# Philadelphia     536
# San Francisco    506
# Seattle          424
#                 ...
# Littleton          1
# Lake Elsinore      1
# Jupiter            1
# Iowa City          1
# Ontario            1
# Name: City, Length: 531, dtype: int64

# %%
df['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
sns.countplot(df['Region'])
plt.show()

# %%
sns.countplot(df['Category'])
plt.show()

# %%
plt.title("Regionwise Category Count")
sns.countplot(df['Category'],hue=df['Region'])
plt.show()

# %%
plt.figure(figsize=(14,8))
plt.pie(df['Sub-Category'].value_counts(),labels=df['Sub-Category'].value_counts().index,autopct="%0.1f%%")
plt.show()
plt.tight_layout()

# %%
#Total Sales
df['Sales'].sum()
# Out:
# 2296195.5903

# %%
#Total Profit
df['Profit'].sum()
# Out:
# 286241.4226

# %%
sns.scatterplot(x='Sales',y='Profit',data=df)
plt.show()

# %%
plt.title("% Sales with respect to Region")
plt.pie(df['Sales'].groupby(df['Region']).sum(),labels=df['Sales'].groupby(df['Region']).sum().index,autopct='%.2f%%')
plt.show()

# %%
plt.title("%Sales with respect to Category")
plt.pie(df['Sales'].groupby(df['Category']).sum(),labels=df['Sales'].groupby(df['Category']).sum().index,autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title("Sales vs Category")
sns.barplot(x='Category',y='Sales',data=df)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title("Sales of each category in each shipmode")
sns.barplot(x='Category',y='Sales',data=df,hue='Ship Mode')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title("Sales vs Sub-Category")
sns.barplot(x='Sub-Category',y='Sales',data=df)
plt.tight_layout()
plt.show()

# %%
plt.title("% Profit with respect to Region")
plt.pie(df['Profit'].groupby(df['Region']).sum(),labels=df['Profit'].groupby(df['Region']).sum().index,autopct='%.2f%%')
plt.show()

# %%
plt.title("% Profit with respect to Category")
plt.pie(df['Profit'].groupby(df['Category']).sum(),labels=df['Profit'].groupby(df['Category']).sum().index,autopct='%.2f%%')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title("Profit vs Category")
sns.barplot(x='Category',y='Profit',data=df)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.title("Profit vs Sub-Category")
sns.barplot(x='Sub-Category',y='Profit',data=df)
plt.show()

# %% [markdown]
# # Observation
# - The Super Store data is of the country United States.
# - The Super Store sell its products in 49 states and 531 cities.
# - The top city and state in terms of frequency are 'New York' and 'California' respectively.
# - The Super Store uses 4 ship modes to deliver the product. They are 'First Class', 'Second Class', 'Standard Class' and 'Same day'. The 'Standard Class' ship mode is used the most by the customers.
# - There are three different segments. 'Consumer', 'Corporate Segment' and 'Home Office'. The 'Consumer' Segment has the highest count.
# - The Western region has the most sales and Southern region has the lowest sales.
# - The superstore sells their products in 3 categories namely 'Office Supplies', 'Furniture' and 'Technology'.
# - Under these categories, the products are further divided into 17 sub-categories.
# - 'Office Supplies' category has the highest count among all the categories and 'Binders' has the highest count among all sub-categories.
# - Sales is highly corelated to profit and quantity.
# - Total Sales = 2296195.5903
# - The Western Region has the most sales i.e. 31.59% of total sales.
# - The Southern Region has the lowest sales i.e. 17.06% of total sales.
# - The 'Technology' category generate the maximum sales.
# - Products under the category of 'Technology' has the highest sales and the preferred Ship Mode is 'Same Day'. 'Second Class' ship mode is the least preferred for products under 'Technology'.
# - The 'Copiers' subcategory generate the maximum sales.
# - Total Profit = 286241.4226
# - The Western Region also contributes the most in total profit i.e.37.85% of total profit.
# - The Central Region contributes the least in total profit i.e. 13.85% of total profit.
# - The 'Technology' category generate the maximum profit.
# - The 'Copiers' subcategory generate the maximum profit.
# - The 'Tables' subcategory generate the maximum loss.
